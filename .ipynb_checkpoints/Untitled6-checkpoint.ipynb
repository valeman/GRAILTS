# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from statsmodels.tsa.stattools import adfuller
from Causal_inference import granger_causality,add_causality_dataset, generate_synthetic
from time import time
import pmdarima as pm
from tqdm import tqdm
from statsmodels.tsa.arima_model import ARMA
from TimeSeries import TimeSeries
from copy import deepcopy

# %%
def plot(x):
    l = np.arange(x.shape[0])
    plt.plot(l, x, c='blue')
    plt.show()

def add_causality(x, y, lag):
    m = y.shape[0]
    for i in range(m-lag):
        y[i + lag] += x[i]
        
def random_walk(drift = 0, m = 128, sd = 1):
    ls = [None] * m
    ls[0] = np.random.normal(0,1)
    for i in range(1, m):
        ls[i] = ls[i-1] + drift + np.random.normal(0,sd)
    return np.array(ls)

def add_rwalk_to_db(ts, sd = 0.1):
    newts = deepcopy(ts)
    for i in range(newts.shape[0]):
        newts[i] += random_walk(m = newts.shape[1], sd = sd)
    return newts

def generate_with_rwalk(sd = 0.1):
    noisydata = np.load('ecgarimanoisy200.npy')
    plot(noisydata[1])
    for i in range(1,200, 2):
        walk = random_walk(m = 96, sd= sd)
        noisydata[i] += walk
    plot(noisydata[1])
    return noisydata

def add_noise(TS, sd):
    n,m  = TS.shape
    newTS = deepcopy(TS)
    for i in range(n):
        newTS[i,:] += np.random.normal(0, sd, m)
    return newTS
        
    
def fit_arima_dataset(TS):
    n,m = TS.shape
    newts = []
    for x in tqdm(ts):
        newts.append(x)
        model = pm.auto_arima(x, seasonal=False)
        res = model.arima_res_
        fitted = res.fittedvalues
        newts.append(fitted)
    newts = np.array(newts)
    
    return newts

# %%
'''Turn a ucr dataset to test data with noise'''
def dataset_to_noisy(TS, sd, name):
    newts = deepcopy(TS)
    newts, _ = fit_arima_dataset(newts)
    causal_db = np.array([newts[i,:] for i in range(0,newts.shape[0],2)])
    effect_db = np.array([newts[i,:] for i in range(1,newts.shape[0],2)])
    assert causal_db.shape == effect_db.shape
    
    effect_db = add_noise(effect_db, sd)
    truemat = np.zeros((causal_db.shape[0], effect_db.shape[0]))
    for i in range(causal_db.shape[0]):
        truemat[i,i] = 1
        
    with open('{}_randomsd{}_causaldb.npy'.format(name, sd), 'wb') as f:
        np.save(f, causal_db)
    with open('{}_randomsd{}_effectdb.npy'.format(name, sd), 'wb') as f:
        np.save(f, effect_db)
    with open('{}_random_split_truemat.npy'.format(name), 'wb') as f:
        np.save(f, truemat)
        
    return causal_db, effect_db, truemat

'''Turn a ucr dataset to test data with random walk as noise'''
def dataset_to_rwalk(TS, sd, name):
    newts = deepcopy(TS)
    newts, _ = fit_arima_dataset(newts)
    causal_db = np.array([newts[i,:] for i in range(0,newts.shape[0],2)])
    effect_db = np.array([newts[i,:] for i in range(1,newts.shape[0],2)])
    assert causal_db.shape == effect_db.shape
    
    for i in range(effect_db.shape[0]):
        walk = random_walk(m = effect_db.shape[1], sd= sd)
        effect_db[i] += walk
        
    truemat = np.zeros((causal_db.shape[0], effect_db.shape[0]))
    for i in range(causal_db.shape[0]):
        truemat[i,i] = 1
        
    with open('{}_rwalksd{}_causaldb.npy'.format(name, sd), 'wb') as f:
        np.save(f, causal_db)
    with open('{}_rwalksd{}_effectdb.npy'.format(name, sd), 'wb') as f:
        np.save(f, effect_db)
    with open('{}_rwalk_split_truemat.npy'.format(name), 'wb') as f:
        np.save(f, truemat)
        
    return causal_db, effect_db, truemat    

def dataset_to_mix(TS, randsd, rwalksd, name):
    newts = deepcopy(TS)
    newts, _ = fit_arima_dataset(newts)
    causal_db = np.array([newts[i,:] for i in range(0,newts.shape[0],2)])
    effect_db = np.array([newts[i,:] for i in range(1,newts.shape[0],2)])
    assert causal_db.shape == effect_db.shape
    
    effect_db = add_noise(effect_db, randsd)
    for i in range(effect_db.shape[0]):
        walk = random_walk(m = effect_db.shape[1], sd= rwalksd)
        effect_db[i] += walk    
    
    truemat = np.zeros((causal_db.shape[0], effect_db.shape[0]))
    for i in range(causal_db.shape[0]):
        truemat[i,i] = 1
        
    with open('{}_mixsd{}_{}_causaldb.npy'.format(name, randsd, rwalksd), 'wb') as f:
        np.save(f, causal_db)
    with open('{}_mixsd{}_{}_effectdb.npy'.format(name, randsd, rwalksd), 'wb') as f:
        np.save(f, effect_db)
    with open('{}_mix_split_truemat.npy'.format(name), 'wb') as f:
        np.save(f, truemat)
        
    return causal_db, effect_db, truemat

# %%
path = 'UCR2018/ECG200/ECG200_TRAIN'

ts, train_labels = TimeSeries.load(path, "UCR")

# %%
causal_db, effect_db, truemat = dataset_to_noisy(ts, sd = 0.1, name = 'ECG')
# Out:
#  14%|███████████▎                                                                     | 14/100 [01:09<08:15,  5.76s/it]C:\Users\kayan\anaconda3\lib\site-packages\pmdarima\arima\_auto_solvers.py:522: ModelFitWarning: Error fitting  ARIMA(4,1,2)(0,0,0)[0] intercept (if you do not want to see these warnings, run with error_action="ignore").
# Traceback:
# Traceback (most recent call last):
#   File "statsmodels\tsa\statespace\_filters\_inversions.pyx", line 411, in statsmodels.tsa.statespace._filters._inversions.dinverse_univariate
# ZeroDivisionError: float division
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\kayan\anaconda3\lib\site-packages\pmdarima\arima\_auto_solvers.py", line 506, in _fit_candidate_model
#     fit.fit(y, X=X, **fit_params)
#   File "C:\Users\kayan\anaconda3\lib\site-packages\pmdarima\arima\arima.py", line 482, in fit
#     self._fit(y, X, **fit_args)
#   File "C:\Users\kayan\anaconda3\lib\site-packages\pmdarima\arima\arima.py", line 403, in _fit
#     fit, self.arima_res_ = _fit_wrapper()
#   File "C:\Users\kayan\anaconda3\lib\site-packages\pmdarima\arima\arima.py", line 393, in _fit_wrapper
#     return arima, arima.fit(start_params=start_params,
#   File "C:\Users\kayan\anaconda3\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py", line 654, in fit
#     mlefit = super(MLEModel, self).fit(start_params, method=method,
#   File "C:\Users\kayan\anaconda3\lib\site-packages\statsmodels\base\model.py", line 518, in fit
#     xopt, retvals, optim_settings = optimizer._fit(f, score, start_params,
#   File "C:\Users\kayan\anaconda3\lib\site-packages\statsmodels\base\optimizer.py", line 215, in _fit
#     xopt, retvals = func(objective, gradient, start_params, fargs, kwargs,
#   File "C:\Users\kayan\anaconda3\lib\site-packages\statsmodels\base\optimizer.py", line 437, in _fit_lbfgs
#     retvals = optimize.fmin_l_bfgs_b(func, start_params, maxiter=maxiter,
#   File "C:\Users\kayan\anaconda3\lib\site-packages\scipy\optimize\lbfgsb.py", line 197, in fmin_l_bfgs_b
#     res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
#   File "C:\Users\kayan\anaconda3\lib\site-packages\scipy\optimize\lbfgsb.py", line 360, in _minimize_lbfgsb
#     f, g = func_and_grad(x)
#   File "C:\Users\kayan\anaconda3\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 201, in fun_and_grad
#     self._update_grad()
#   File "C:\Users\kayan\anaconda3\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 171, in _update_grad
#     self._update_grad_impl()
#   File "C:\Users\kayan\anaconda3\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 91, in update_grad
#     self.g = approx_derivative(fun_wrapped, self.x, f0=self.f,
#   File "C:\Users\kayan\anaconda3\lib\site-packages\scipy\optimize\_numdiff.py", line 426, in approx_derivative
#     return _dense_difference(fun_wrapped, x0, f0, h,
#   File "C:\Users\kayan\anaconda3\lib\site-packages\scipy\optimize\_numdiff.py", line 497, in _dense_difference
#     df = fun(x) - f0
#   File "C:\Users\kayan\anaconda3\lib\site-packages\scipy\optimize\_numdiff.py", line 377, in fun_wrapped
#     f = np.atleast_1d(fun(x, *args, **kwargs))
#   File "C:\Users\kayan\anaconda3\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 70, in fun_wrapped
#     return fun(x, *args)
#   File "C:\Users\kayan\anaconda3\lib\site-packages\statsmodels\base\model.py", line 500, in f
#     return -self.loglike(params, *args) / nobs
#   File "C:\Users\kayan\anaconda3\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py", line 889, in loglike
#     loglike = self.ssm.loglike(complex_step=complex_step, **kwargs)
#   File "C:\Users\kayan\anaconda3\lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py", line 977, in loglike
#     kfilter = self._filter(**kwargs)
#   File "C:\Users\kayan\anaconda3\lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py", line 900, in _filter
#     kfilter()
#   File "statsmodels\tsa\statespace\_kalman_filter.pyx", line 2000, in statsmodels.tsa.statespace._kalman_filter.dKalmanFilter.__call__
#   File "statsmodels\tsa\statespace\_kalman_filter.pyx", line 2080, in statsmodels.tsa.statespace._kalman_filter.dKalmanFilter.__next__
#   File "statsmodels\tsa\statespace\_filters\_inversions.pyx", line 413, in statsmodels.tsa.statespace._filters._inversions.dinverse_univariate
# numpy.linalg.LinAlgError: Non-positive-definite forecast error covariance matrix encountered at period 1
#
#   warnings.warn(warning_str, ModelFitWarning)
#  53%|██████████████████████████████████████████▉                                      | 53/100 [04:19<03:49,  4.88s/it]C:\Users\kayan\anaconda3\lib\site-packages\pmdarima\arima\_auto_solvers.py:522: ModelFitWarning: Error fitting  ARIMA(5,1,2)(0,0,0)[0]           (if you do not want to see these warnings, run with error_action="ignore").
# Traceback:
# Traceback (most recent call last):
#   File "C:\Users\kayan\anaconda3\lib\site-packages\pmdarima\arima\_auto_solvers.py", line 506, in _fit_candidate_model
#     fit.fit(y, X=X, **fit_params)
#   File "C:\Users\kayan\anaconda3\lib\site-packages\pmdarima\arima\arima.py", line 482, in fit
#     self._fit(y, X, **fit_args)
#   File "C:\Users\kayan\anaconda3\lib\site-packages\pmdarima\arima\arima.py", line 403, in _fit
#     fit, self.arima_res_ = _fit_wrapper()
#   File "C:\Users\kayan\anaconda3\lib\site-packages\pmdarima\arima\arima.py", line 393, in _fit_wrapper
#     return arima, arima.fit(start_params=start_params,
#   File "C:\Users\kayan\anaconda3\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py", line 654, in fit
#     mlefit = super(MLEModel, self).fit(start_params, method=method,
#   File "C:\Users\kayan\anaconda3\lib\site-packages\statsmodels\base\model.py", line 518, in fit
#     xopt, retvals, optim_settings = optimizer._fit(f, score, start_params,
#   File "C:\Users\kayan\anaconda3\lib\site-packages\statsmodels\base\optimizer.py", line 215, in _fit
#     xopt, retvals = func(objective, gradient, start_params, fargs, kwargs,
#   File "C:\Users\kayan\anaconda3\lib\site-packages\statsmodels\base\optimizer.py", line 437, in _fit_lbfgs
#     retvals = optimize.fmin_l_bfgs_b(func, start_params, maxiter=maxiter,
#   File "C:\Users\kayan\anaconda3\lib\site-packages\scipy\optimize\lbfgsb.py", line 197, in fmin_l_bfgs_b
#     res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
#   File "C:\Users\kayan\anaconda3\lib\site-packages\scipy\optimize\lbfgsb.py", line 360, in _minimize_lbfgsb
#     f, g = func_and_grad(x)
#   File "C:\Users\kayan\anaconda3\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 200, in fun_and_grad
#     self._update_fun()
#   File "C:\Users\kayan\anaconda3\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 166, in _update_fun
#     self._update_fun_impl()
#   File "C:\Users\kayan\anaconda3\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 73, in update_fun
#     self.f = fun_wrapped(self.x)
#   File "C:\Users\kayan\anaconda3\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 70, in fun_wrapped
#     return fun(x, *args)
#   File "C:\Users\kayan\anaconda3\lib\site-packages\statsmodels\base\model.py", line 500, in f
#     return -self.loglike(params, *args) / nobs
#   File "C:\Users\kayan\anaconda3\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py", line 889, in loglike
#     loglike = self.ssm.loglike(complex_step=complex_step, **kwargs)
#   File "C:\Users\kayan\anaconda3\lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py", line 977, in loglike
#     kfilter = self._filter(**kwargs)
#   File "C:\Users\kayan\anaconda3\lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py", line 897, in _filter
#     self._initialize_state(prefix=prefix, complex_step=complex_step)
#   File "C:\Users\kayan\anaconda3\lib\site-packages\statsmodels\tsa\statespace\representation.py", line 949, in _initialize_state
#     self._statespaces[prefix].initialize(self.initialization,
#   File "statsmodels\tsa\statespace\_representation.pyx", line 1341, in statsmodels.tsa.statespace._representation.dStatespace.initialize
#   File "statsmodels\tsa\statespace\_representation.pyx", line 1334, in statsmodels.tsa.statespace._representation.dStatespace.initialize
#   File "statsmodels\tsa\statespace\_initialization.pyx", line 288, in statsmodels.tsa.statespace._initialization.dInitialization.initialize
#   File "statsmodels\tsa\statespace\_initialization.pyx", line 406, in statsmodels.tsa.statespace._initialization.dInitialization.initialize_stationary_stationary_cov
#   File "statsmodels\tsa\statespace\_tools.pyx", line 1206, in statsmodels.tsa.statespace._tools._dsolve_discrete_lyapunov
# numpy.linalg.LinAlgError: LU decomposition error.
#
#   warnings.warn(warning_str, ModelFitWarning)
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [07:56<00:00,  4.77s/it]

# %%
plot(causal_db[0])
plot(effect_db[0])
